# %%
! pip install gensim

# %%
import gensim.downloader as gensim_api

model = gensim_api.load("word2vec-google-news-300")
model
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
# Find embedding for given word

word = "trump"
embedding = model[word]
print(f"EMbedding for the word {word} is : {embedding}")
# Out:
# EMbedding for the word trump is : [-0.07910156  0.12158203 -0.00842285  0.30664062 -0.15429688  0.10742188
#   0.08398438 -0.0267334  -0.01831055  0.1484375  -0.15429688 -0.14160156
#  -0.21679688  0.11767578 -0.20605469  0.1796875   0.42578125  0.07128906
#   0.20117188 -0.19628906  0.04956055  0.05932617 -0.09375     0.20898438
#   0.01696777  0.01385498 -0.37109375 -0.00872803 -0.03491211 -0.03320312
#   0.10742188 -0.01879883 -0.390625    0.26757812 -0.12158203  0.08300781
#  -0.02612305  0.34960938  0.12890625  0.28515625  0.359375   -0.01104736
#   0.05126953  0.08300781  0.05322266 -0.17285156  0.14941406  0.23925781
#   0.56640625  0.19824219 -0.30078125  0.17480469 -0.11328125 -0.25976562
#  -0.31054688 -0.03088379 -0.49609375 -0.30664062  0.07763672 -0.21777344
#   0.27539062  0.15039062  0.22949219  0.30859375  0.08154297 -0.03613281
#  -0.26953125  0.14160156 -0.19921875  0.04199219  0.00075531 -0.16210938
# ...
